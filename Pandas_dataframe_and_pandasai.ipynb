# %% [markdown]
# <a href="https://colab.research.google.com/github/likit/MUMT-Coders/blob/main/Pandas_dataframe_and_pandasai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This is AI demo.**

# %%
print('Welcome to Google colab.')
# Out:
# Welcome to Google colab.

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
len(df)  # count number of rows
# Out:
# 17000

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df['total_rooms']
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64

# %%
df['total_rooms'] < 1000
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 16995    False
# 16996    False
# 16997    False
# 16998    False
# 16999    False
# Name: total_rooms, Length: 17000, dtype: bool

# %%
index = df['total_rooms'] < 1000

# %%
df[index]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -114.56     33.69                17.0        720.0           174.0
# 7        -114.59     34.83                41.0        812.0           168.0
# 17       -114.65     32.79                21.0         44.0            33.0
# 19       -114.67     33.92                17.0         97.0            24.0
# 21       -114.73     33.43                24.0        796.0           243.0
# ...          ...       ...                 ...          ...             ...
# 16938    -124.13     40.55                38.0        544.0            89.0
# 16944    -124.14     40.67                23.0        580.0           117.0
# 16951    -124.15     40.81                50.0        340.0            74.0
# 16969    -124.17     40.80                52.0        661.0           316.0
# 16982    -124.18     40.62                35.0        952.0           178.0
#
# ...

# %%
index_bedrooms = df['total_bedrooms'] < 1000
index_pop = df['population'] < 300

# %%
df[(index_bedrooms & index_pop)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17       -114.65     32.79                21.0         44.0            33.0
# 19       -114.67     33.92                17.0         97.0            24.0
# 21       -114.73     33.43                24.0        796.0           243.0
# 22       -114.94     34.55                20.0        350.0            95.0
# 23       -114.98     33.82                15.0        644.0           129.0
# ...          ...       ...                 ...          ...             ...
# 16851    -123.43     40.22                20.0        133.0            35.0
# 16852    -123.48     40.79                15.0        619.0           160.0
# 16853    -123.48     40.34                19.0        518.0           108.0
# 16938    -124.13     40.55                38.0        544.0            89.0
# 16951    -124.15     40.81                50.0        340.0            74.0
#
# ...

# %%
# !pip install pandasai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.20
#     Uninstalling SQLAlchemy-2.0.20:
#       Successfully uninstalled SQLAlchemy-2.0.20
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from pandasai import SmartDataframe

# %%
from pandasai.llm import OpenAI

# %%
llm = OpenAI(api_token='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')

# %%
sdf = SmartDataframe('sample_data/california_housing_train.csv',
                     config={'llm': llm})

# %%
sdf.head(5)
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]

# %%
sdf.chat('Show me the last 10 rows')
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 16990    -124.22     41.73  ...         1.7038             78300.0
# 16991    -124.23     41.75  ...         2.4805             73200.0
# 16992    -124.23     40.81  ...         3.3462             50800.0
# 16993    -124.23     40.54  ...         3.0806            106700.0
# 16994    -124.25     40.28  ...         1.9417             76100.0
# 16995    -124.26     40.58  ...         2.3571            111400.0
# 16996    -124.27     40.69  ...         2.5179             79000.0
# 16997    -124.30     41.84  ...         3.0313            103600.0
# 16998    -124.30     41.80  ...         1.9797             85800.0
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [10 rows x 9 columns]

# %%
sdf.chat('plot histogram of housing median age')

# %%
sdf.chat('show me rows with total bedrooms less than 1000')
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 2        -114.56     33.69  ...         1.6509             85700.0
# 3        -114.57     33.64  ...         3.1917             73400.0
# 4        -114.57     33.57  ...         1.9250             65500.0
# 5        -114.58     33.63  ...         3.3438             74000.0
# 6        -114.58     33.61  ...         2.6768             82400.0
# ...          ...       ...  ...            ...                 ...
# 16995    -124.26     40.58  ...         2.3571            111400.0
# 16996    -124.27     40.69  ...         2.5179             79000.0
# 16997    -124.30     41.84  ...         3.0313            103600.0
# 16998    -124.30     41.80  ...         1.9797             85800.0
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [15423 rows x 9 columns]

# %%
sdf.chat('show me the total rows that have total bedrooms less than 1000'
' and population under 300'
' and show the last row'
)
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 16951    -124.15     40.81  ...           1.75             67500.0
#
# [1 rows x 9 columns]

# %%
sdf = SmartDataframe('Lab-TAT-demo-data.xlsx',
                     config={'llm': llm})

# %%
sdf.head(5)
# Out:
#   Orderer Group Name  ... Medical Validation DateTime
# 0                OPD  ...         2023-06-01 01:28:37
# 1                IPD  ...         2023-06-01 06:19:04
# 2                IPD  ...         2023-06-01 06:18:52
# 3                IPD  ...         2023-06-01 07:34:10
# 4                IPD  ...         2023-06-01 06:03:11
#
# [5 rows x 15 columns]

# %%
tat = sdf.chat('add column TAT from minutes difference between LIS Order DateTime and'
' Medical Validation DateTime for each row keep inplace=True')

# %%
tat.columns
# Out:
# Index(['Orderer Group Name', 'Orderer Name', 'Priority', 'Form',
#        'Analyte Group', 'Order No.', 'Analyte No.', 'Analyte Name', 'TechVal',
#        'MedVal', 'LIS Order DateTime', 'HIS Order DateTime',
#        'TestResult DateTime', 'Technical Validation DateTime',
#        'Medical Validation DateTime', 'TAT'],
#       dtype='object')

# %%
tat.chat('count rows with TAT greater than 60')
# Out:
# 150

# %%
tat.chat('percentage of rows with TAT greater than 60')
# Out:
# 24.154589371980677

# %%
tat.chat('plot pie chart of rows with TAT greater than 60 grouped by analyte name')

# %%
tat.chat('show me number of rows grouped by Orderer name and '
'analyte name in descending order')
# Out:
#                      Orderer Name Analyte Name  Count
# 44              งานเทคนิคการแพทย์          MCV     90
# 55                ศูนย์ตรวจสุขภาพ          MCV     48
# 70         อายุรกรรมทั่วไป2 ชั้น2          MCV     43
# 68         อายุรกรรมทั่วไป2 ชั้น2        HDL-C     41
# 15        คลินิกตรวจสุขภาพพนักงาน          MCV     30
# ..                            ...          ...    ...
# 18                   คลินิกนรีเวช          MCV      1
# 17                   คลินิกนรีเวช        HBsAg      1
# 7   คลินิก DMไทรอยด์และต่อมไร้ท่อ        HDL-C      1
# 2      ER/ศัลยกรรมกระดูก(นอกเวลา)          MCV      1
# 72                        ไม่ระบุ          MCV      1
#
# [73 rows x 3 columns]
